# %% [markdown]
# # Front Matter: CASA0007 Quantitative Methods
#
# ## Title: Assessment 3 - Written Investigation
#
# ### Student ID: 21203086

# %% [markdown]
# # Reproducible Analysis

# %% [markdown]
# ## Introduction-overview

# %% [markdown]
# This notebook holds the analysis for the
# After a first exploration of the datasets with visualisations that seek to quantify the current picture

# %% [markdown]
# Data used for this analysis were obtained from the following sources:
# * Online database for the Sustainable Development Report 2021: <https://dashboards.sdgindex.org/static/downloads/files/SDR%202021%20-%20Database.xlsx>
# * education data : <https://stats.oecd.org/viewhtml.aspx?datasetcode=EAG_NEAC&lang=en>
# * world map: <https://www.naturalearthdata.com/http//www.naturalearthdata.com/download/110m/cultural/ne_110m_admin_0_countries.zip>

# %% [markdown]
# ## Libraries

# %%
# import the main libraries
import os
import numpy as np
import pandas as pd
import geopandas as gpd
import matplotlib.cm as cm
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data import

# %% [markdown]
# ### Map

# %%
world = gpd.read_file("Data/geo/ne_110m_admin_0_countries/ne_110m_admin_0_countries.shp")
world.plot()
# Out:
# <AxesSubplot:>

# %%
world.head()
# Out:
#         featurecla  scalerank  LABELRANK                   SOVEREIGNT SOV_A3  \
# 0  Admin-0 country          1          6                         Fiji    FJI
# 1  Admin-0 country          1          3  United Republic of Tanzania    TZA
# 2  Admin-0 country          1          7               Western Sahara    SAH
# 3  Admin-0 country          1          2                       Canada    CAN
# 4  Admin-0 country          1          2     United States of America    US1
#
#    ADM0_DIF  LEVEL               TYPE                        ADMIN ADM0_A3  \
# 0         0      2  Sovereign country                         Fiji     FJI
# 1         0      2  Sovereign country  United Republic of Tanzania     TZA
# 2         0      2      Indeterminate               Western Sahara     SAH
# 3         0      2  Sovereign country                       Canada     CAN
# 4         1      2            Country     United States of America     USA
#
#    ...     FCLASS_TR     FCLASS_ID     FCLASS_PL  FCLASS_GR FCLASS_IT  \
# 0  ...          None          None          None       None      None
# 1  ...          None          None          None       None      None
# 2  ...  Unrecognized  Unrecognized  Unrecognized       None      None
# 3  ...          None          None          None       None      None
# 4  ...          None          None          None       None      None
#
#       FCLASS_NL  FCLASS_SE FCLASS_BD FCLASS_UA  \
# 0          None       None      None      None
# 1          None       None      None      None
# 2  Unrecognized       None      None      None
# 3          None       None      None      None
# 4          None       None      None      None
#
#                                             geometry
# 0  MULTIPOLYGON (((180.00000 -16.06713, 180.00000...
# 1  POLYGON ((33.90371 -0.95000, 34.07262 -1.05982...
# 2  POLYGON ((-8.66559 27.65643, -8.66512 27.58948...
# 3  MULTIPOLYGON (((-122.84000 49.00000, -122.9742...
# 4  MULTIPOLYGON (((-122.84000 49.00000, -120.0000...
#
# [5 rows x 162 columns]

# %%
type(world)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
world['ISO_A3']
# Out:
# 0      FJI
# 1      TZA
# 2      ESH
# 3      CAN
# 4      USA
#       ...
# 172    SRB
# 173    MNE
# 174    -99
# 175    TTO
# 176    SSD
# Name: ISO_A3, Length: 177, dtype: object

# %%
column_list= world.columns.values
column_list
# Out:
# array(['featurecla', 'scalerank', 'LABELRANK', 'SOVEREIGNT', 'SOV_A3',
#        'ADM0_DIF', 'LEVEL', 'TYPE', 'ADMIN', 'ADM0_A3', 'GEOU_DIF',
#        'GEOUNIT', 'GU_A3', 'SU_DIF', 'SUBUNIT', 'SU_A3', 'BRK_DIFF',
#        'NAME', 'NAME_LONG', 'BRK_A3', 'BRK_NAME', 'BRK_GROUP', 'ABBREV',
#        'POSTAL', 'FORMAL_EN', 'FORMAL_FR', 'NAME_CIAWF', 'NOTE_ADM0',
#        'NOTE_BRK', 'NAME_SORT', 'NAME_ALT', 'MAPCOLOR7', 'MAPCOLOR8',
#        'MAPCOLOR9', 'MAPCOLOR13', 'POP_EST', 'POP_RANK', 'POP_YEAR',
#        'GDP_MD', 'GDP_YEAR', 'ECONOMY', 'INCOME_GRP', 'FIPS_10', 'ISO_A2',
#        'ISO_A2_EH', 'ISO_A3', 'ISO_A3_EH', 'ISO_N3', 'ISO_N3_EH', 'UN_A3',
#        'WB_A2', 'WB_A3', 'WOE_ID', 'WOE_ID_EH', 'WOE_NOTE', 'ADM0_A3_IS',
#        'ADM0_A3_US', 'ADM0_A3_FR', 'ADM0_A3_RU', 'ADM0_A3_ES',
#        'ADM0_A3_CN', 'ADM0_A3_TW', 'ADM0_A3_IN', 'ADM0_A3_NP',
#        'ADM0_A3_PK', 'ADM0_A3_DE', 'ADM0_A3_GB', 'ADM0_A3_BR',
#        'ADM0_A3_IL', 'ADM0_A3_PS', 'ADM0_A3_SA', 'ADM0_A3_EG',
#        'ADM0_A3_MA', 'ADM0_A3_PT', 'ADM0_A3_AR', 'ADM0_A3_JP',
#        'ADM0_A3_KO', 'ADM0_A3_VN', 'ADM0_A3_TR', 'ADM0_A3_ID',
#        'ADM0_A3_PL', 'ADM0_A3_GR', 'ADM0_A3_IT', 'ADM0_A3_NL',
#        'ADM0_A3_SE', 'ADM0_A3_BD', 'ADM0_A3_UA', 'ADM0_A3_UN',
#        'ADM0_A3_WB', 'CONTINENT', 'REGION_UN', 'SUBREGION', 'REGION_WB',
#        'NAME_LEN', 'LONG_LEN', 'ABBREV_LEN', 'TINY', 'HOMEPART',
#        'MIN_ZOOM', 'MIN_LABEL', 'MAX_LABEL', 'NE_ID', 'WIKIDATAID',
#        'NAME_AR', 'NAME_BN', 'NAME_DE', 'NAME_EN', 'NAME_ES', 'NAME_FA',
#        'NAME_FR', 'NAME_EL', 'NAME_HE', 'NAME_HI', 'NAME_HU', 'NAME_ID',
#        'NAME_IT', 'NAME_JA', 'NAME_KO', 'NAME_NL', 'NAME_PL', 'NAME_PT',
#        'NAME_RU', 'NAME_SV', 'NAME_TR', 'NAME_UK', 'NAME_UR', 'NAME_VI',
#        'NAME_ZH', 'NAME_ZHT', 'FCLASS_ISO', 'FCLASS_US', 'FCLASS_FR',
#        'FCLASS_RU', 'FCLASS_ES', 'FCLASS_CN', 'FCLASS_TW', 'FCLASS_IN',
#        'FCLASS_NP', 'FCLASS_PK', 'FCLASS_DE', 'FCLASS_GB', 'FCLASS_BR',
#        'FCLASS_IL', 'FCLASS_PS', 'FCLASS_SA', 'FCLASS_EG', 'FCLASS_MA',
#        'FCLASS_PT', 'FCLASS_AR', 'FCLASS_JP', 'FCLASS_KO', 'FCLASS_VN',
#        'FCLASS_TR', 'FCLASS_ID', 'FCLASS_PL', 'FCLASS_GR', 'FCLASS_IT',
#        'FCLASS_NL', 'FCLASS_SE', 'FCLASS_BD', 'FCLASS_UA', 'geometry'],
#       dtype=object)

# %%
world.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
world = world.to_crs("+proj=moll +lon_0=0 +x_0=0 +y_0=0 +ellps=WGS84 +datum=WGS84 +units=m +no_defs")
world.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### SDG data

# %%
# Load in the data 
df = pd.read_excel('https://dashboards.sdgindex.org/static/downloads/files/SDR%202021%20-%20Database.xlsx?raw=true', sheet_name="Raw Data")
df.head(3)
# Out:
#   Country Code ISO3      Country Regions used for the SDG Index & Dashboard  \
# 0               AFG  Afghanistan                        E. Europe & C. Asia
# 1               ALB      Albania                        E. Europe & C. Asia
# 2               DZA      Algeria                                       MENA
#
#    Population in 2020  Poverty headcount ratio at $1.90/day (%)  \
# 0       38,928,341.00                                       NaN
# 1        2,877,800.00                                      0.16
# 2       43,851,043.00                                      0.37
#
#    Poverty headcount ratio at $3.20/day (%)  \
# 0                                       NaN
# 1                                      8.50
# 2                                      2.89
#
#    Poverty rate after taxes and transfers (%)  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
#
#    Prevalence of undernourishment (%)  \
# 0                               29.90
# 1                                3.60
# 2                                2.80
#
#    Prevalence of stunting in children under 5 years of age (%)  \
# 0                                              38.20
# 1                                              11.30
# 2                                              11.70
#
#    Prevalence of wasting in children under 5 years of age (%)  ...  \
# 0                                               5.10           ...
# 1                                               1.60           ...
# 2                                               4.10           ...
#
#    Press Freedom Index (best 0-100 worst)  \
# 0                                   37.70
# 1                                   30.25
# 2                                   45.52
#
#    Access to and affordability of justice (worst 0–1 best)  \
# 0                                               0.49
# 1                                               0.53
# 2                                               0.55
#
#    Persons held in prison (per 100,000 population)  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
#
#    Government spending on health and education (% of GDP)  \
# 0                                               4.54
# 1                                               6.45
# 2                                               8.43
#
#    For high-income and all OECD DAC countries: International concessional public fi  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
#
#    Other countries: Government revenue excluding grants (% of GDP)  \
# 0                                              13.04
# 1                                              25.34
# 2                                              40.42
#
#    Corporate Tax Haven Score (best 0-100 worst)  \
# 0                                          0.00
# 1                                          0.00
# 2                                          0.00
#
#    Financial Secrecy Score (best 0-100 worst)  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
#
#    Shifted profits of multinationals (US$ billion)  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
#
#    Statistical Performance Index (worst 0-100 best)
# 0                                             49.76
# 1                                             75.38
# 2                                             55.15
#
# [3 rows x 125 columns]

# %%
# size of dataframe
print(f"Data frame is {df.shape[0]:,} x {df.shape[1]}")
# Out:
# Data frame is 193 x 125

# %%
# extract the column names
cols=df.columns
print(cols)
print()
print(f"The dataset has {len(cols)} columns")
# Out:
# Index(['Country Code ISO3', 'Country',
#        'Regions used for the SDG Index & Dashboard', 'Population in 2020',
#        'Poverty headcount ratio at $1.90/day (%)',
#        'Poverty headcount ratio at $3.20/day (%)',
#        'Poverty rate after taxes and transfers (%)',
#        'Prevalence of undernourishment (%)',
#        'Prevalence of stunting in children under 5 years of age (%)',
#        'Prevalence of wasting in children under 5 years of age (%)',
#        ...
#        'Press Freedom Index (best 0-100 worst)',
#        'Access to and affordability of justice (worst 0–1 best)',
#        'Persons held in prison (per 100,000 population)',
#        'Government spending on health and education (% of GDP)',
#        'For high-income and all OECD DAC countries: International concessional public fi',
#        'Other countries: Government revenue excluding grants (% of GDP)',
#        'Corporate Tax Haven Score (best 0-100 worst)',
#        'Financial Secrecy Score (best 0-100 worst)',
#        'Shifted profits of multinationals (US$ billion)',
#        'Statistical Performance Index (worst 0-100 best)'],
#       dtype='object', length=125)
#
# The dataset has 125 columns

# %%
# store the columns of interest in a list
sub_cols=["Country", "Country Code ISO3"
          "Adolescent fertility rate (births per 1,000 females aged 15 to 19)",
          "Subjective well-being (average ladder score, worst 0-10 best)",
          "Literacy rate (% of population aged 15 to 24)",
          "Tertiary educational attainment (% of population aged 25 to 34)",
          "Demand for family planning satisfied by modern methods (% of females aged 15 to ",
          "Ratio of female-to-male mean years of education received (%)",
          "Seats held by women in national parliament (%)",
          "Gender wage gap (% of male median wage)",
          "CO₂ emissions from fuel combustion for electricity and heating per total electri",
          "Unemployment rate (% of total labor force)",
          "Gini coefficient adjusted for top income",
          "Palma ratio",
          "Government spending on health and education (% of GDP)",
          "Female share of graduates from STEM fields at the tertiary level (%)"
          ]
# create a subframe with the stored columns
df= df[sub_cols]

# %%
# change settings to display all rows
pd.set_option('display.max_rows', None)
# investigate NA values by printing out the count of NA values per column 
df.isna().sum().sort_values(ascending=False)
# Out:
# Population who feel safe walking alone at night in the city or area where they l    193
# Yield gap closure (% of potential yield)                                            166
# Gender gap in time spent doing unpaid work (minutes/day)                            164
# Gap in internet access by income (percentage points)                                161
# Population with rent overburden (%)                                                 160
# Non-recycled municipal solid waste (kg/capita/day)                                  159
# Gap in life expectancy at birth among regions (years)                               158
# Gap in self-reported health status by income (percentage points)                    158
# Researchers (per 1,000 employed population)                                         158
# Female share of graduates from STEM fields at the tertiary level (%)                158
# Poverty rate after taxes and transfers (%)                                          157
# Shifted profits of multinationals (US$ billion)                                     157
# Elderly poverty rate (% of population aged 66 or over)                              157
# Population using safely managed water services (%)                                  157
# Youth not in employment, education or training (NEET) (% of population aged 15 t    157
# Gender wage gap (% of male median wage)                                             156
# Daily smokers (% of population aged 15 and over)                                    156
# PISA score (worst 0-600 best)                                                       156
# Participation rate in pre-primary organized learning (% of children aged 4 to 6)    156
# Tertiary educational attainment (% of population aged 25 to 34)                     156
# Share of renewable energy in total primary energy supply (%)                        156
# Resilient students in science (% of 15-year-olds)                                   156
# Population using safely managed sanitation services (%)                             156
# Carbon Pricing Score at EUR60/tCO₂ (%, worst 0-100 best)                            156
# Underachievers in science (% of 15-year-olds)                                       156
# Variation in science performance explained by socio-economic status (%)             156
# Persons held in prison (per 100,000 population)                                     156
# Financial Secrecy Score (best 0-100 worst)                                          156
# Triadic patent families filed (per million population)                              156
# Employment-to-population ratio (%)                                                  156
# For high-income and all OECD DAC countries: International concessional public fi    154
# Other countries: Government revenue excluding grants (% of GDP)                      84
# Exports of hazardous pesticides (tonnes per million population)                      77
# Fish caught from overexploited or collapsed stocks (% of total catch)                76
# New HIV infections (per 1,000 uninfected population)                                 75
# Fundamental labor rights are effectively guaranteed (worst 0–1 best)                 67
# Access to and affordability of justice (worst 0–1 best)                              67
# Children involved in child labor (% of population aged 5 to 14)                      65
# CO₂ emissions from fuel combustion for electricity and heating per total electri     53
# Mean area that is protected in marine sites important to biodiversity (%)            53
# Property Rights (worst 1-7 best)                                                     52
# Proportion of urban population living in slums (%)                                   50
# Fish caught that are then discarded (%)                                              46
# Ocean Health Index: Clean Waters score (worst 0-100 best)                            46
# Fish caught by trawling or dredging (%)                                              46
# Mean area that is protected in freshwater sites important to biodiversity (%)        45
# Victims of modern slavery (per 1,000 population)                                     42
# Expenditure on research and development (% of GDP)                                   40
# Palma ratio                                                                          40
# Adults with an account at a bank or other financial institution or with a mobile     39
# Literacy rate (% of population aged 15 to 24)                                        37
# Satisfaction with public transport (%)                                               33
# Subjective well-being (average ladder score, worst 0-10 best)                        33
# Gini coefficient adjusted for top income                                             32
# Poverty headcount ratio at $1.90/day (%)                                             32
# Poverty headcount ratio at $3.20/day (%)                                             32
# Prevalence of undernourishment (%)                                                   30
# Logistics Performance Index: Quality of trade and transport-related infrastructu     28
# Permanent deforestation (% of forest area, 5-year average)                           27
# CO₂ emissions embodied in fossil fuel exports (kg/capita)                            26
# Access to improved water source, piped (% of urban population)                       25
# Ratio of female-to-male mean years of education received (%)                         22
# Birth registrations with civil authority (% of children under age 5)                 20
# Statistical Performance Index (worst 0-100 best)                                     20
# Press Freedom Index (best 0-100 worst)                                               19
# Terrestrial and freshwater biodiversity threats embodied in imports (per million     18
# Marine biodiversity threats embodied in imports (per million population)             18
# Cereal yield (tonnes per hectare of harvested land)                                  17
# Human Trophic Level (best 2-3 worst)                                                 17
# CO₂ emissions embodied in imports (tCO₂/capita)                                      17
# Freshwater withdrawal (% of available freshwater resources)                          17
# Production-based SO₂ emissions (kg/capita)                                           17
# SO₂ emissions embodied in imports (kg/capita)                                        17
# Production-based nitrogen emissions (kg/capita)                                      17
# Scarce water consumption embodied in imports (m³/capita)                             17
# Nitrogen emissions embodied in imports (kg/capita)                                   17
# Fatal work-related accidents embodied in imports (per 100,000 population)            17
# Corruption Perception Index (worst 0-100 best)                                       16
# Electronic waste (kg/capita)                                                         16
# Unemployment rate (% of total labor force)                                           15
# Ratio of female-to-male labor force participation rate (%)                           15
# Net primary enrollment rate (%)                                                      13
# Demand for family planning satisfied by modern methods (% of females aged 15 to      13
# Unsentenced detainees (% of prison population)                                       12
# Adjusted GDP growth (%)                                                              11
# Lower secondary completion rate (%)                                                  10
# Age-standardized death rate due to cardiovascular disease, cancer, diabetes, or      10
# Age-standardized death rate attributable to household air pollution and ambient      10
# Traffic deaths (per 100,000 population)                                              10
# Life expectancy at birth (years)                                                     10
# Adolescent fertility rate (births per 1,000 females aged 15 to 19)                   10
# Births attended by skilled health personnel (%)                                      10
# Universal health coverage (UHC) index of service coverage (worst 0-100 best)         10
# Maternal mortality rate (per 100,000 live births)                                    10
# Government spending on health and education (% of GDP)                               10
# Sustainable Nitrogen Management Index (best 0-1.41 worst)                             7
# Prevalence of stunting in children under 5 years of age (%)                           7
# Prevalence of wasting in children under 5 years of age (%)                            7
# Municipal solid waste (kg/capita/day)                                                 7
# Mean area that is protected in terrestrial sites important to biodiversity (%)        6
# Prevalence of obesity, BMI ≥ 30 (% of adult population)                               5
# Population with access to clean fuels and technology for cooking (%)                  4
# CO₂ emissions from fossil fuel combustion and cement production (tCO2/capita)         3
# Corporate Tax Haven Score (best 0-100 worst)                                          3
# Annual mean concentration of particulate matter of less than 2.5 microns in diam      2
# Homicides (per 100,000 population)                                                    2
# Surviving infants who received 2 WHO-recommended vaccines (%)                         1
# Red List Index of species survival (worst 0-1 best)                                   1
# Anthropogenic wastewater that receives treatment (%)                                  1
# Mobile broadband subscriptions (per 100 population)                                   1
# Incidence of tuberculosis (per 100,000 population)                                    1
# Mortality rate, under-5 (per 1,000 live births)                                       1
# Neonatal mortality rate (per 1,000 live births)                                       1
# Population in 2020                                                                    0
# Regions used for the SDG Index & Dashboard                                            0
# Scientific and technical journal articles (per 1,000 population)                      0
# Exports of major conventional weapons (TIV constant million USD per 100,000 popu      0
# Seats held by women in national parliament (%)                                        0
# Population using at least basic drinking water services (%)                           0
# Population using at least basic sanitation services (%)                               0
# Population with access to electricity (%)                                             0
# Country                                                                               0
# Population using the internet (%)                                                     0
# The Times Higher Education Universities Ranking: Average score of top 3 universi      0
# Country Code ISO3                                                                     0
# dtype: int64

# %%
# change settings back 
pd.reset_option('all')
# Out:
# As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead.
#
# : boolean
#     use_inf_as_null had been deprecated and will be removed in a future
#     version. Use `use_inf_as_na` instead.
# /opt/conda/envs/sds2021/lib/python3.9/site-packages/pandas/_config/config.py:630: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead.
#   warnings.warn(d.msg, FutureWarning)
# /opt/conda/envs/sds2021/lib/python3.9/site-packages/pandas/_config/config.py:630: FutureWarning:
# : boolean
#     use_inf_as_null had been deprecated and will be removed in a future
#     version. Use `use_inf_as_na` instead.
#
#   warnings.warn(d.msg, FutureWarning)

# %%
#df.set_index('Country', inplace=True)
df.head()
# Out:
#   Country Code ISO3      Country Regions used for the SDG Index & Dashboard  \
# 0               AFG  Afghanistan                        E. Europe & C. Asia
# 1               ALB      Albania                        E. Europe & C. Asia
# 2               DZA      Algeria                                       MENA
# 3               AND      Andorra                        E. Europe & C. Asia
# 4               AGO       Angola                                     Africa
#
#    Population in 2020  Poverty headcount ratio at $1.90/day (%)  \
# 0          38928341.0                                       NaN
# 1           2877800.0                                      0.16
# 2          43851043.0                                      0.37
# 3             77265.0                                       NaN
# 4          32866268.0                                     53.85
#
#    Poverty headcount ratio at $3.20/day (%)  \
# 0                                       NaN
# 1                                      8.50
# 2                                      2.89
# 3                                       NaN
# 4                                     75.70
#
#    Poverty rate after taxes and transfers (%)  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
#    Prevalence of undernourishment (%)  \
# 0                               29.90
# 1                                3.60
# 2                                2.80
# 3                                1.17
# 4                               18.60
#
#    Prevalence of stunting in children under 5 years of age (%)  \
# 0                                              38.20
# 1                                              11.30
# 2                                              11.70
# 3                                               2.58
# 4                                              37.60
#
#    Prevalence of wasting in children under 5 years of age (%)  ...  \
# 0                                                5.1           ...
# 1                                                1.6           ...
# 2                                                4.1           ...
# 3                                                0.7           ...
# 4                                                4.9           ...
#
#    Press Freedom Index (best 0-100 worst)  \
# 0                                   37.70
# 1                                   30.25
# 2                                   45.52
# 3                                   23.23
# 4                                   33.92
#
#    Access to and affordability of justice (worst 0–1 best)  \
# 0                                              0.487
# 1                                              0.532
# 2                                              0.550
# 3                                                NaN
# 4                                              0.476
#
#    Persons held in prison (per 100,000 population)  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
#    Government spending on health and education (% of GDP)  \
# 0                                              4.545
# 1                                              6.453
# 2                                              8.431
# 3                                              7.710
# 4                                              4.490
#
#    For high-income and all OECD DAC countries: International concessional public fi  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Other countries: Government revenue excluding grants (% of GDP)  \
# 0                                             13.039
# 1                                             25.343
# 2                                             40.424
# 3                                                NaN
# 4                                             16.361
#
#    Corporate Tax Haven Score (best 0-100 worst)  \
# 0                                         0.000
# 1                                         0.000
# 2                                         0.000
# 3                                        69.049
# 4                                         0.000
#
#    Financial Secrecy Score (best 0-100 worst)  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
#    Shifted profits of multinationals (US$ billion)  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
#    Statistical Performance Index (worst 0-100 best)
# 0                                            49.756
# 1                                            75.383
# 2                                            55.149
# 3                                               NaN
# 4                                            54.946
#
# [5 rows x 125 columns]

# %% [markdown]
# ### First dataset exploration

# %%
# check the datatype 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193 entries, 0 to 192
# Data columns (total 15 columns):
#  #   Column                                                                            Non-Null Count  Dtype
# ---  ------                                                                            --------------  -----
#  0   Country                                                                           193 non-null    object
#  1   Adolescent fertility rate (births per 1,000 females aged 15 to 19)                183 non-null    float64
#  2   Subjective well-being (average ladder score, worst 0-10 best)                     160 non-null    float64
#  3   Literacy rate (% of population aged 15 to 24)                                     156 non-null    float64
#  4   Tertiary educational attainment (% of population aged 25 to 34)                   37 non-null     float64
#  5   Demand for family planning satisfied by modern methods (% of females aged 15 to   180 non-null    float64
#  6   Ratio of female-to-male mean years of education received (%)                      171 non-null    float64
#  7   Seats held by women in national parliament (%)                                    193 non-null    float64
#  8   Gender wage gap (% of male median wage)                                           37 non-null     float64
#  9   CO₂ emissions from fuel combustion for electricity and heating per total electri  140 non-null    float64
#  10  Unemployment rate (% of total labor force)                                        178 non-null    float64
#  11  Gini coefficient adjusted for top income                                          161 non-null    float64
#  12  Palma ratio                                                                       153 non-null    float64
#  13  Government spending on health and education (% of GDP)                            183 non-null    float64
#  14  Female share of graduates from STEM fields at the tertiary level (%)              35 non-null     float64
# dtypes: float64(14), object(1)
# memory usage: 22.7+ KB

# %% [markdown]
# After inspecting the data the key things to note are:
# * Many NA values in key fields
# * All are floats, no need for converting
# * Standardised data, (percentages, ratios etc)

# %%
#subset the countries with no info for higher education  
df_no_info= df[df["Tertiary educational attainment (% of population aged 25 to 34)"].isna()]
df_no_info
# Out:
#            Country  \
# 0      Afghanistan
# 1          Albania
# 2          Algeria
# 3          Andorra
# 4           Angola
# ..             ...
# 188  Venezuela, RB
# 189        Vietnam
# 190    Yemen, Rep.
# 191         Zambia
# 192       Zimbabwe
#
#      Adolescent fertility rate (births per 1,000 females aged 15 to 19)  \
# 0                                               65.141
# 1                                               19.572
# 2                                                9.834
# 3                                                  NaN
# 4                                              147.958
# ..                                                 ...
# 188                                             84.979
# 189                                             29.152
# 190                                             59.162
# 191                                            118.305
# 192                                             83.249
#
#      Subjective well-being (average ladder score, worst 0-10 best)  \
# 0                                                  2.4
# 1                                                  5.4
# 2                                                  4.7
# 3                                                  NaN
# 4                                                  3.8
# ..                                                 ...
# 188                                                5.1
# 189                                                5.5
# 190                                                4.2
# 191                                                4.8
# 192                                                3.2
#
#      Literacy rate (% of population aged 15 to 24)  \
# 0                                           65.421
# 1                                           99.330
# 2                                           97.427
# 3                                              NaN
# 4                                           77.431
# ..                                             ...
# 188                                         98.760
# 189                                         98.408
# 190                                         77.000
# 191                                         92.092
# 192                                         90.428
#
#      Tertiary educational attainment (% of population aged 25 to 34)  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 188                                                NaN
# 189                                                NaN
# 190                                                NaN
# 191                                                NaN
# 192                                                NaN
#
#      Demand for family planning satisfied by modern methods (% of females aged 15 to   \
# 0                                                 42.2
# 1                                                  6.3
# 2                                                 77.2
# 3                                                  NaN
# 4                                                 29.8
# ..                                                 ...
# 188                                               82.0
# 189                                               69.6
# 190                                               40.5
# 191                                               65.9
# 192                                               84.8
#
#      Ratio of female-to-male mean years of education received (%)  \
# 0                                               31.667
# 1                                               91.509
# 2                                               92.771
# 3                                               98.113
# 4                                               62.500
# ..                                                 ...
# 188                                            106.000
# 189                                             93.023
# 190                                             56.863
# 191                                             76.829
# 192                                             91.011
#
#      Seats held by women in national parliament (%)  \
# 0                                            27.016
# 1                                            29.508
# 2                                            25.758
# 3                                            46.429
# 4                                            30.000
# ..                                              ...
# 188                                          22.156
# 189                                          26.721
# 190                                           0.332
# 191                                          16.766
# 192                                          31.852
#
#      Gender wage gap (% of male median wage)  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# ..                                       ...
# 188                                      NaN
# 189                                      NaN
# 190                                      NaN
# 191                                      NaN
# 192                                      NaN
#
#      CO₂ emissions from fuel combustion for electricity and heating per total electri  \
# 0                                                  NaN
# 1                                                0.508
# 2                                                1.905
# 3                                                  NaN
# 4                                                1.609
# ..                                                 ...
# 188                                              1.165
# 189                                              0.982
# 190                                              2.342
# 191                                              0.419
# 192                                              1.279
#
#      Unemployment rate (% of total labor force)  \
# 0                                         11.73
# 1                                         11.70
# 2                                         12.83
# 3                                           NaN
# 4                                          7.70
# ..                                          ...
# 188                                        9.14
# 189                                        2.27
# 190                                       13.42
# 191                                       12.17
# 192                                        5.73
#
#      Gini coefficient adjusted for top income  Palma ratio  \
# 0                                         NaN          NaN
# 1                                      41.682        1.272
# 2                                      31.522        0.991
# 3                                         NaN          NaN
# 4                                      45.075        3.443
# ..                                        ...          ...
# 188                                    55.329          NaN
# 189                                    35.621        1.478
# 190                                    49.027        1.564
# 191                                    62.669        4.989
# 192                                    43.134        2.305
#
#      Government spending on health and education (% of GDP)  \
# 0                                                4.545
# 1                                                6.453
# 2                                                8.431
# 3                                                7.710
# 4                                                4.490
# ..                                                 ...
# 188                                              8.579
# 189                                              6.864
# 190                                              5.649
# 191                                              6.547
# 192                                              7.196
#
#      Female share of graduates from STEM fields at the tertiary level (%)
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 188                                                NaN
# 189                                                NaN
# 190                                                NaN
# 191                                                NaN
# 192                                                NaN
#
# [156 rows x 15 columns]

# %%
print(df_no_info["Country"].tolist())
# Out:
# ['Afghanistan', 'Albania', 'Algeria', 'Andorra', 'Angola', 'Antigua and Barbuda', 'Argentina', 'Armenia', 'Azerbaijan', 'Bahamas, The', 'Bahrain', 'Bangladesh', 'Barbados', 'Belarus', 'Belize', 'Benin', 'Bhutan', 'Bolivia', 'Bosnia and Herzegovina', 'Botswana', 'Brazil', 'Brunei Darussalam', 'Bulgaria', 'Burkina Faso', 'Burundi', 'Cabo Verde', 'Cambodia', 'Cameroon', 'Central African Republic', 'Chad', 'China', 'Comoros', 'Congo, Dem. Rep.', 'Congo, Rep.', 'Costa Rica', "Cote d'Ivoire", 'Croatia', 'Cuba', 'Cyprus', 'Djibouti', 'Dominica', 'Dominican Republic', 'Ecuador', 'Egypt, Arab Rep.', 'El Salvador', 'Equatorial Guinea', 'Eritrea', 'Eswatini', 'Ethiopia', 'Fiji', 'Gabon', 'Gambia, The', 'Georgia', 'Ghana', 'Grenada', 'Guatemala', 'Guinea', 'Guinea-Bissau', 'Guyana', 'Haiti', 'Honduras', 'India', 'Indonesia', 'Iran, Islamic Rep.', 'Iraq', 'Jamaica', 'Jordan', 'Kazakhstan', 'Kenya', 'Kiribati', 'Korea, Dem. Rep.', 'Kuwait', 'Kyrgyz Republic', 'Lao PDR', 'Lebanon', 'Lesotho', 'Liberia', 'Libya', 'Liechtenstein', 'Madagascar', 'Malawi', 'Malaysia', 'Maldives', 'Mali', 'Malta', 'Marshall Islands', 'Mauritania', 'Mauritius', 'Micronesia, Fed. Sts.', 'Moldova', 'Monaco', 'Mongolia', 'Montenegro', 'Morocco', 'Mozambique', 'Myanmar', 'Namibia', 'Nauru', 'Nepal', 'Nicaragua', 'Niger', 'Nigeria', 'North Macedonia', 'Oman', 'Pakistan', 'Palau', 'Panama', 'Papua New Guinea', 'Paraguay', 'Peru', 'Philippines', 'Qatar', 'Romania', 'Russian Federation', 'Rwanda', 'Samoa', 'San Marino', 'Sao Tome and Principe', 'Saudi Arabia', 'Senegal', 'Serbia', 'Seychelles', 'Sierra Leone', 'Singapore', 'Solomon Islands', 'Somalia', 'South Africa', 'South Sudan', 'Sri Lanka', 'St. Kitts and Nevis', 'St. Lucia', 'St. Vincent and the Grenadines', 'Sudan', 'Suriname', 'Syrian Arab Republic', 'Tajikistan', 'Tanzania', 'Thailand', 'Timor-Leste', 'Togo', 'Tonga', 'Trinidad and Tobago', 'Tunisia', 'Turkmenistan', 'Tuvalu', 'Uganda', 'Ukraine', 'United Arab Emirates', 'Uruguay', 'Uzbekistan', 'Vanuatu', 'Venezuela, RB', 'Vietnam', 'Yemen, Rep.', 'Zambia', 'Zimbabwe']

# %% [markdown]
# NOTE: plot on a map?

# %%
# first remove the rows(countries) with NA values
df_info = df.dropna(axis=0, how="any")
print(df_info.index.values)
# Out:
# [ 34  36  45  55  66  74  82  90  94 100 111 138 139 154 159 177]

# %% [markdown]
# Very few countries left to work with

# %%
# merge the census data with the previously joined dataframe
world_joined = pd.merge( world, df ,left_on = 'ISO_A3', right_on = "Country Code ISO3", how = "left")

# %%
world_joined.plot(figsize=(12,8),
                  legend=True,
                  column='Female share of graduates from STEM fields at the tertiary level (%)', 
                  cmap='OrRd',
                  missing_kwds= dict(color = "lightgrey")
                 );

# %%
ax = world_joined.plot(column="Female share of graduates from STEM fields at the tertiary level (%)",
           legend=True,
           scheme="quantiles",
           k=4,
           cmap="crest",
           figsize=(15, 10),
           missing_kwds={"color": "lightgrey",
                         "edgecolor": "grey",
                         "hatch": "///",
                         "label": "Missing values",},)

ax.set_axis_off();

# %% [markdown]
# ## repeat

# %%
# Load in the data 
df2 = pd.read_excel('https://dashboards.sdgindex.org/static/downloads/files/SDR%202021%20-%20Database.xlsx?raw=true', sheet_name="Raw Data")
df2.head(3)
# Out:
#   Country Code ISO3      Country Regions used for the SDG Index & Dashboard  \
# 0               AFG  Afghanistan                        E. Europe & C. Asia
# 1               ALB      Albania                        E. Europe & C. Asia
# 2               DZA      Algeria                                       MENA
#
#    Population in 2020  Poverty headcount ratio at $1.90/day (%)  \
# 0       38,928,341.00                                       NaN
# 1        2,877,800.00                                      0.16
# 2       43,851,043.00                                      0.37
#
#    Poverty headcount ratio at $3.20/day (%)  \
# 0                                       NaN
# 1                                      8.50
# 2                                      2.89
#
#    Poverty rate after taxes and transfers (%)  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
#
#    Prevalence of undernourishment (%)  \
# 0                               29.90
# 1                                3.60
# 2                                2.80
#
#    Prevalence of stunting in children under 5 years of age (%)  \
# 0                                              38.20
# 1                                              11.30
# 2                                              11.70
#
#    Prevalence of wasting in children under 5 years of age (%)  ...  \
# 0                                               5.10           ...
# 1                                               1.60           ...
# 2                                               4.10           ...
#
#    Press Freedom Index (best 0-100 worst)  \
# 0                                   37.70
# 1                                   30.25
# 2                                   45.52
#
#    Access to and affordability of justice (worst 0–1 best)  \
# 0                                               0.49
# 1                                               0.53
# 2                                               0.55
#
#    Persons held in prison (per 100,000 population)  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
#
#    Government spending on health and education (% of GDP)  \
# 0                                               4.54
# 1                                               6.45
# 2                                               8.43
#
#    For high-income and all OECD DAC countries: International concessional public fi  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
#
#    Other countries: Government revenue excluding grants (% of GDP)  \
# 0                                              13.04
# 1                                              25.34
# 2                                              40.42
#
#    Corporate Tax Haven Score (best 0-100 worst)  \
# 0                                          0.00
# 1                                          0.00
# 2                                          0.00
#
#    Financial Secrecy Score (best 0-100 worst)  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
#
#    Shifted profits of multinationals (US$ billion)  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
#
#    Statistical Performance Index (worst 0-100 best)
# 0                                             49.76
# 1                                             75.38
# 2                                             55.15
#
# [3 rows x 125 columns]

# %%
# store the columns of interest in a list
sub_cols2=["Country",
         # "Adolescent fertility rate (births per 1,000 females aged 15 to 19)",
           "Poverty rate after taxes and transfers (%)",
          # "Subjective well-being (average ladder score, worst 0-10 best)",
         # "Literacy rate (% of population aged 15 to 24)",
         # "Tertiary educational attainment (% of population aged 25 to 34)",
         "Demand for family planning satisfied by modern methods (% of females aged 15 to ",
          #"Ratio of female-to-male mean years of education received (%)",
         # "Seats held by women in national parliament (%)",
          "Gender wage gap (% of male median wage)",
         # "CO₂ emissions from fuel combustion for electricity and heating per total electri",
          "Unemployment rate (% of total labor force)",
          #"Gini coefficient adjusted for top income",
          #"Palma ratio",
          "Government spending on health and education (% of GDP)",
           "Press Freedom Index (best 0-100 worst)",
         # "Female share of graduates from STEM fields at the tertiary level (%)"
          ]
# create a subframe with the stored columns
df2= df2[sub_cols2]
#df2.set_index('Country', inplace=True)
df2.head()
# Out:
#        Country  Poverty rate after taxes and transfers (%)  \
# 0  Afghanistan                                         NaN
# 1      Albania                                         NaN
# 2      Algeria                                         NaN
# 3      Andorra                                         NaN
# 4       Angola                                         NaN
#
#    Demand for family planning satisfied by modern methods (% of females aged 15 to   \
# 0                                              42.20
# 1                                               6.30
# 2                                              77.20
# 3                                                NaN
# 4                                              29.80
#
#    Gender wage gap (% of male median wage)  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
#    Unemployment rate (% of total labor force)  \
# 0                                       11.73
# 1                                       11.70
# 2                                       12.83
# 3                                         NaN
# 4                                        7.70
#
#    Government spending on health and education (% of GDP)  \
# 0                                               4.54
# 1                                               6.45
# 2                                               8.43
# 3                                               7.71
# 4                                               4.49
#
#    Press Freedom Index (best 0-100 worst)
# 0                                   37.70
# 1                                   30.25
# 2                                   45.52
# 3                                   23.23
# 4                                   33.92

# %%
# first remove the rows(countries) with NA values
df2_info = df2.dropna(axis=0, how="any")

# %%
#print(df2_info.index.values)
print(df2_info["Country"].tolist())
# Out:
# ['Australia', 'Austria', 'Belgium', 'Canada', 'Chile', 'Czech Republic', 'Denmark', 'Estonia', 'Finland', 'France', 'Germany', 'Greece', 'Hungary', 'Ireland', 'Israel', 'Italy', 'Japan', 'Korea, Rep.', 'Latvia', 'Lithuania', 'Mexico', 'Netherlands', 'New Zealand', 'Norway', 'Poland', 'Portugal', 'Slovak Republic', 'Slovenia', 'Spain', 'Sweden', 'Switzerland', 'Turkey', 'United Kingdom', 'United States']

# %%
# size of dataframe
print(f"Data frame is {df2_info.shape[0]:,} x {df2_info.shape[1]}")
# Out:
# Data frame is 34 x 7

# %%
df2_info.head(36)
# Out:
#              Country  Poverty rate after taxes and transfers (%)  \
# 8          Australia                                       12.40
# 9            Austria                                        9.40
# 16           Belgium                                        8.20
# 31            Canada                                       11.80
# 34             Chile                                       16.50
# 45    Czech Republic                                        6.10
# 46           Denmark                                        6.10
# 55           Estonia                                       16.30
# 59           Finland                                        6.50
# 60            France                                        8.50
# 64           Germany                                       10.40
# 66            Greece                                       12.10
# 74           Hungary                                       17.90
# 80           Ireland                                        9.00
# 81            Israel                                       16.90
# 82             Italy                                       13.90
# 84             Japan                                       15.70
# 90       Korea, Rep.                                       16.70
# 94            Latvia                                       17.50
# 100        Lithuania                                       15.50
# 111           Mexico                                       16.60
# 123      Netherlands                                        8.30
# 124      New Zealand                                       10.90
# 129           Norway                                        8.40
# 138           Poland                                        9.80
# 139         Portugal                                       10.40
# 153  Slovak Republic                                        7.70
# 154         Slovenia                                        7.50
# 159            Spain                                       14.20
# 166           Sweden                                        8.90
# 167      Switzerland                                        9.20
# 177           Turkey                                       17.20
# 183   United Kingdom                                       11.70
# 184    United States                                       17.80
#
#      Demand for family planning satisfied by modern methods (% of females aged 15 to   \
# 8                                                85.60
# 9                                                88.00
# 16                                               90.10
# 31                                               90.90
# 34                                               84.80
# 45                                               85.70
# 46                                               87.70
# 55                                               80.30
# 59                                               90.40
# 60                                               95.50
# 64                                               91.00
# 66                                               63.50
# 74                                               80.20
# 80                                               87.70
# 81                                               68.30
# 82                                               72.00
# 84                                               67.30
# 90                                               81.80
# 94                                               80.50
# 100                                              69.70
# 111                                              79.80
# 123                                              88.60
# 124                                              85.60
# 129                                              88.60
# 138                                              71.80
# 139                                              77.60
# 153                                              79.20
# 154                                              75.80
# 159                                              83.50
# 166                                              86.70
# 167                                              88.90
# 177                                              60.10
# 183                                              86.50
# 184                                              78.40
#
#      Gender wage gap (% of male median wage)  \
# 8                                      11.70
# 9                                      14.90
# 16                                      4.20
# 31                                     17.60
# 34                                     12.50
# 45                                     14.70
# 46                                      4.90
# 55                                     28.30
# 59                                     18.90
# 60                                     13.70
# 64                                     15.30
# 66                                      4.50
# 74                                      5.10
# 80                                     10.60
# 81                                     22.70
# 82                                      5.60
# 84                                     23.50
# 90                                     32.50
# 94                                     21.10
# 100                                    12.50
# 111                                    18.80
# 123                                    14.10
# 124                                     6.50
# 129                                     5.00
# 138                                    11.50
# 139                                     9.60
# 153                                    13.90
# 154                                     5.00
# 159                                    11.50
# 166                                     7.60
# 167                                    15.10
# 177                                     6.90
# 183                                    16.00
# 184                                    18.50
#
#      Unemployment rate (% of total labor force)  \
# 8                                          6.61
# 9                                          5.77
# 16                                         6.01
# 31                                         9.48
# 34                                        11.51
# 45                                         2.94
# 46                                         5.66
# 55                                         6.46
# 59                                         7.83
# 60                                         8.62
# 64                                         4.31
# 66                                        16.85
# 74                                         4.35
# 80                                         5.92
# 81                                         4.61
# 82                                         9.31
# 84                                         2.97
# 90                                         4.07
# 94                                         8.19
# 100                                        8.43
# 111                                        4.71
# 123                                        4.09
# 124                                        4.55
# 129                                        4.62
# 138                                        3.55
# 139                                        7.20
# 153                                        6.79
# 154                                        5.17
# 159                                       15.67
# 166                                        8.45
# 167                                        4.94
# 177                                       13.92
# 183                                        4.34
# 184                                        8.31
#
#      Government spending on health and education (% of GDP)  \
# 8                                                11.54
# 9                                                12.91
# 16                                               14.23
# 31                                               13.21
# 34                                               10.07
# 45                                               10.18
# 46                                               16.26
# 55                                                9.89
# 59                                               13.48
# 60                                               13.71
# 64                                               13.78
# 66                                                7.97
# 74                                                9.30
# 80                                                8.63
# 81                                               10.96
# 82                                               10.45
# 84                                               12.39
# 90                                                8.75
# 94                                                8.09
# 100                                               8.14
# 111                                               7.21
# 123                                              11.65
# 124                                              13.18
# 129                                              16.49
# 138                                               9.06
# 139                                              10.80
# 153                                               9.24
# 154                                              10.79
# 159                                              10.53
# 166                                              16.84
# 167                                               8.84
# 177                                               5.94
# 183                                              13.30
# 184                                              13.47
#
#      Press Freedom Index (best 0-100 worst)
# 8                                     20.21
# 9                                     15.78
# 16                                    12.57
# 31                                    15.29
# 34                                    27.31
# 45                                    23.57
# 46                                     8.13
# 55                                    12.61
# 59                                     7.93
# 60                                    22.92
# 64                                    12.16
# 66                                    28.80
# 74                                    30.84
# 80                                    12.60
# 81                                    30.84
# 82                                    23.69
# 84                                    28.86
# 90                                    23.70
# 94                                    18.56
# 100                                   21.19
# 111                                   45.45
# 123                                    9.96
# 124                                   10.69
# 129                                    7.84
# 138                                   28.65
# 139                                   11.83
# 153                                   22.67
# 154                                   22.64
# 159                                   22.16
# 166                                    9.25
# 167                                   10.62
# 177                                   50.02
# 183                                   22.93
# 184                                   23.85

# %%
# investigate NA values by printing out the count of NA values per column 
df2_info.isnull().sum().sort_values(ascending=False)
# Out:
# Country                                                                             0
# Poverty rate after taxes and transfers (%)                                          0
# Demand for family planning satisfied by modern methods (% of females aged 15 to     0
# Gender wage gap (% of male median wage)                                             0
# Unemployment rate (% of total labor force)                                          0
# Government spending on health and education (% of GDP)                              0
# Press Freedom Index (best 0-100 worst)                                              0
# dtype: int64

# %% [markdown]
# # EDUCATION INFO

# %%
# Load in the data 
edu = pd.read_excel("Data/raw/education_data.xlsx", sheet_name="OECD.Stat export", header=7, skipfooter=7)
edu.head(10)
# Out:
#   ISCED 2011 A education level Unnamed: 1        Unnamed: 2  Unnamed: 3  \
# 0                          NaN        NaN               NaN         NaN
# 1                      Measure        NaN               NaN         NaN
# 2                      Country        NaN              Unit         NaN
# 3                    Australia        NaN  Percentage, 2020         NaN
# 4                      Austria        NaN  Percentage, 2020         NaN
# 5                      Belgium        NaN  Percentage, 2020         NaN
# 6                       Canada        NaN  Percentage, 2020         NaN
# 7                        Chile        NaN  Percentage, 2017         NaN
# 8                     Colombia        NaN  Percentage, 2020         NaN
# 9                   Costa Rica        NaN  Percentage, 2020         NaN
#
#   Below upper secondary education Unnamed: 5  \
# 0                             NaN        NaN
# 1                           Value         SE
# 2                             NaN        NaN
# 3                       16.298603   0.324406
# 4                         16.9282   0.167495
# 5                       18.701988   0.193475
# 6                        6.248758         ..
# 7                       32.452843   0.193342
# 8                       38.924721   0.117054
# 9                       55.552193   0.638954
#
#   Below upper secondary education.1 Unnamed: 7           Unnamed: 8  \
# 0       Less than primary education        NaN    Primary education
# 1                             Value         SE                Value
# 2                               NaN        NaN                  NaN
# 3                                 0          0             3.153098
# 4                                ..         ..             1.098733
# 5                          2.517085   0.077724             4.093136
# 6                                ..         ..             1.758395
# 7                          7.160082   0.106469             5.330394
# 8                                ..         ..                   ..
# 9                         10.724995   0.397885            25.792068
#
#   Unnamed: 9  ... Tertiary education Unnamed: 23  \
# 0        NaN  ...                NaN         NaN
# 1         SE  ...              Value          SE
# 2        NaN  ...                NaN         NaN
# 3   0.153482  ...          54.412212    0.437441
# 4    0.04656  ...          34.013531    0.211603
# 5   0.098309  ...          46.957001    0.247631
# 6         ..  ...          66.451424          ..
# 7   0.092764  ...          25.628315    0.180285
# 8         ..  ...          27.101116    0.106707
# 9   0.562552  ...          26.449753    0.567149
#
#                Tertiary education.1 Unnamed: 25  \
# 0    Short-cycle tertiary education         NaN
# 1                             Value          SE
# 2                               NaN         NaN
# 3                         13.102977     0.29637
# 4                         13.665793    0.153418
# 5                          0.832893    0.045094
# 6                         28.968805          ..
# 7                          9.428301    0.120673
# 8                                ..          ..
# 9                           6.59643    0.319176
#
#                             Unnamed: 26 Unnamed: 27  \
# 0    Bachelor’s or equivalent education         NaN
# 1                                 Value          SE
# 2                                   NaN         NaN
# 3                             30.855103    0.405687
# 4                              5.237334    0.099504
# 5                             27.869328    0.222466
# 6                             25.829525          ..
# 7                             14.663694    0.146078
# 8                             27.101116    0.106707
# 9                             16.889963    0.481765
#
#                           Unnamed: 28 Unnamed: 29  \
# 0    Master’s or equivalent education         NaN
# 1                               Value          SE
# 2                                 NaN         NaN
# 3                            8.871507    0.249731
# 4                           14.043162    0.155182
# 5                           17.767202    0.189659
# 6                            11.65309          ..
# 7                             1.53632     0.05079
# 8                                  ..          ..
# 9                            2.847715    0.213879
#
#                           Unnamed: 30 Unnamed: 31
# 0    Doctoral or equivalent education         NaN
# 1                               Value          SE
# 2                                 NaN         NaN
# 3                            1.582625    0.109616
# 4                             1.06724    0.045895
# 5                            0.487576    0.034562
# 6                                  ..          ..
# 7                                  ..          ..
# 8                                  ..          ..
# 9                                  ..          ..
#
# [10 rows x 32 columns]

# %%
# filter out the columns needed
tet_edu = edu[["ISCED 2011 A education level","Tertiary education"]]

# %%
tet_edu.head()
# Out:
#   ISCED 2011 A education level Tertiary education
# 0                          NaN                NaN
# 1                      Measure              Value
# 2                      Country                NaN
# 3                    Australia          54.412212
# 4                      Austria          34.013531

# %%
tet_edu.tail(13)
# Out:
#          ISCED 2011 A education level Tertiary education
# 39                     United Kingdom          51.790306
# 40                      United States          53.423653
# 41                     OECD - Average          42.041134
# 42  European Union 22 members in OECD          41.402802
# 43                                G20          34.765573
# 44                 Non-OECD Economies          39.529755
# 45                                NaN          23.052433
# 46                                NaN           8.562923
# 47                                NaN           9.837578
# 48                                NaN          13.308873
# 49                                NaN          63.460545
# 50                                NaN           23.19838
# 51                                NaN          16.851519

# %%
# drop the unneccssary rows
tet_edu.drop(tet_edu.index[41:52], inplace=True)
tet_edu.tail()
# Out:
# /opt/conda/envs/sds2021/lib/python3.9/site-packages/pandas/core/frame.py:4901: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#    ISCED 2011 A education level Tertiary education
# 36                       Sweden          52.181118
# 37                  Switzerland          42.166286
# 38                       Turkey          20.753014
# 39               United Kingdom          51.790306
# 40                United States          53.423653

# %%
# drop the unnecessary rows
tet_edu.drop(tet_edu.index[0:3], inplace=True)
tet_edu.head()
# Out:
# /opt/conda/envs/sds2021/lib/python3.9/site-packages/pandas/core/frame.py:4901: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#   ISCED 2011 A education level Tertiary education
# 3                    Australia          54.412212
# 4                      Austria          34.013531
# 5                      Belgium          46.957001
# 6                       Canada          66.451424
# 7                        Chile          25.628315

# %%
#rename column names
tet_edu.rename(columns = {'ISCED 2011 A education level':'Country_name', 'Tertiary education':'Women with tertiary educ perc'}, inplace = True)
# Out:
# /opt/conda/envs/sds2021/lib/python3.9/site-packages/pandas/core/frame.py:5034: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
# investigate NA values by printing out the count of NA values per column 
tet_edu.isna().sum().sort_values(ascending=False)
# Out:
# Country_name                     0
# Women with tertiary educ perc    0
# dtype: int64

# %%
# check the name of Korea
tet_edu.head(34)
# Out:
#        Country_name Women with tertiary educ perc
# 3         Australia                     54.412212
# 4           Austria                     34.013531
# 5           Belgium                     46.957001
# 6            Canada                     66.451424
# 7             Chile                     25.628315
# 8          Colombia                     27.101116
# 9        Costa Rica                     26.449753
# 10   Czech Republic                     27.334427
# 11          Denmark                     45.869457
# 12          Estonia                     52.436687
# 13          Finland                     56.023224
# 14           France                     42.535744
# 15          Germany                     28.971186
# 16           Greece                     34.508327
# 17          Hungary                     31.325165
# 18          Iceland                     47.555538
# 19          Ireland                     53.423771
# 20           Israel                     55.079689
# 21            Italy                     23.014601
# 22            Japan                     53.901878
# 23            Korea                     48.524532
# 24        Lithuania                     51.099312
# 25           Latvia                     46.251678
# 26       Luxembourg                      52.49231
# 27           Mexico                     18.965326
# 28      Netherlands                     43.321602
# 29      New Zealand                     43.271767
# 30           Norway                     51.226639
# 31           Poland                      38.83564
# 32         Portugal                     32.995258
# 33  Slovak Republic                     31.597046
# 34         Slovenia                     43.015697
# 35            Spain                     42.658867
# 36           Sweden                     52.181118

# %%
#change country name for Korea, assuming it is South Korea
tet_edu.at[23,'Country_name']="Korea, Rep."

# %%
tet_edu.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 38 entries, 3 to 40
# Data columns (total 2 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country_name                   38 non-null     object
#  1   Women with tertiary educ perc  38 non-null     object
# dtypes: object(2)
# memory usage: 1.9+ KB

# %%
tet_edu['Women with tertiary educ perc']=tet_edu['Women with tertiary educ perc'].astype('float')
# Out:
# /opt/conda/envs/sds2021/lib/python3.9/site-packages/pandas/core/frame.py:3607: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._set_item(key, value)

# %%
tet_edu.describe()
# Out:
#        Women with tertiary educ perc
# count                      38.000000
# mean                       42.041134
# std                        11.783185
# min                        18.965326
# 25%                        31.946599
# 50%                        43.296684
# 75%                        52.083415
# max                        66.451424

# %% [markdown]
# ## merge

# %%
# merge 
df_merged = pd.merge( df2_info, tet_edu ,left_on = "Country", right_on = "Country_name", how = "left").drop(columns=["Country_name"])
df_merged.head()
# Out:
#      Country  Poverty rate after taxes and transfers (%)  \
# 0  Australia                                       12.40
# 1    Austria                                        9.40
# 2    Belgium                                        8.20
# 3     Canada                                       11.80
# 4      Chile                                       16.50
#
#    Demand for family planning satisfied by modern methods (% of females aged 15 to   \
# 0                                              85.60
# 1                                              88.00
# 2                                              90.10
# 3                                              90.90
# 4                                              84.80
#
#    Gender wage gap (% of male median wage)  \
# 0                                    11.70
# 1                                    14.90
# 2                                     4.20
# 3                                    17.60
# 4                                    12.50
#
#    Unemployment rate (% of total labor force)  \
# 0                                        6.61
# 1                                        5.77
# 2                                        6.01
# 3                                        9.48
# 4                                       11.51
#
#    Government spending on health and education (% of GDP)  \
# 0                                              11.54
# 1                                              12.91
# 2                                              14.23
# 3                                              13.21
# 4                                              10.07
#
#    Press Freedom Index (best 0-100 worst)  Women with tertiary educ perc
# 0                                   20.21                          54.41
# 1                                   15.78                          34.01
# 2                                   12.57                          46.96
# 3                                   15.29                          66.45
# 4                                   27.31                          25.63

# %%
# investigate NA values by printing out the count of NA values per column 
df_merged.isna().sum().sort_values(ascending=False)
# Out:
# Country                                                                             0
# Poverty rate after taxes and transfers (%)                                          0
# Demand for family planning satisfied by modern methods (% of females aged 15 to     0
# Gender wage gap (% of male median wage)                                             0
# Unemployment rate (% of total labor force)                                          0
# Government spending on health and education (% of GDP)                              0
# Press Freedom Index (best 0-100 worst)                                              0
# Women with tertiary educ perc                                                       0
# dtype: int64

# %%
# size of dataframe
print(f"Data frame is {df_merged.shape[0]:,} x {df_merged.shape[1]}")
# Out:
# Data frame is 34 x 8

# %%
df_merged.set_index("Country", inplace=True)

df_merged.head(3)
# Out:
#            Poverty rate after taxes and transfers (%)  \
# Country
# Australia                                       12.40
# Austria                                          9.40
# Belgium                                          8.20
#
#            Demand for family planning satisfied by modern methods (% of females aged 15 to   \
# Country
# Australia                                              85.60
# Austria                                                88.00
# Belgium                                                90.10
#
#            Gender wage gap (% of male median wage)  \
# Country
# Australia                                    11.70
# Austria                                      14.90
# Belgium                                       4.20
#
#            Unemployment rate (% of total labor force)  \
# Country
# Australia                                        6.61
# Austria                                          5.77
# Belgium                                          6.01
#
#            Government spending on health and education (% of GDP)  \
# Country
# Australia                                              11.54
# Austria                                                12.91
# Belgium                                                14.23
#
#            Press Freedom Index (best 0-100 worst)  \
# Country
# Australia                                   20.21
# Austria                                     15.78
# Belgium                                     12.57
#
#            Women with tertiary educ perc
# Country
# Australia                          54.41
# Austria                            34.01
# Belgium                            46.96

# %%
#rename column names
df_merged.rename(columns = { 
                            'Demand for family planning satisfied by modern methods (% of females aged 15 to ':'Contraception',
                            'Gender wage gap (% of male median wage)':"Gender wage gap",
                            #'CO₂ emissions from fuel combustion for electricity and heating per total electri': 'CO₂ emissions',
                            'Unemployment rate (% of total labor force)': 'Unemployment',
                            'Poverty rate after taxes and transfers (%)':'Poverty rate',
                            'Government spending on health and education (% of GDP)':'Education spendings',
                            'Press Freedom Index (best 0-100 worst)': "Press Freedom"
                    }, inplace = True)

# %%
df_merged.head(5)
# Out:
#            Poverty rate  Contraception  Gender wage gap  Unemployment  \
# Country
# Australia         12.40          85.60            11.70          6.61
# Austria            9.40          88.00            14.90          5.77
# Belgium            8.20          90.10             4.20          6.01
# Canada            11.80          90.90            17.60          9.48
# Chile             16.50          84.80            12.50         11.51
#
#            Education spendings  Press Freedom  Women with tertiary educ perc
# Country
# Australia                11.54          20.21                          54.41
# Austria                  12.91          15.78                          34.01
# Belgium                  14.23          12.57                          46.96
# Canada                   13.21          15.29                          66.45
# Chile                    10.07          27.31                          25.63

# %%
df_merged.describe()
# Out:
#        Poverty rate  Contraception  Gender wage gap  Unemployment  \
# count         34.00          34.00            34.00         34.00
# mean          11.94          81.53            13.38          6.95
# std            3.90           8.65             7.01          3.40
# min            6.10          60.10             4.20          2.94
# 25%            8.60          77.80             7.08          4.56
# 50%           11.30          84.15            13.10          5.96
# 75%           16.15          87.92            17.20          8.40
# max           17.90          95.50            32.50         16.85
#
#        Education spendings  Press Freedom  Women with tertiary educ perc
# count                34.00          34.00                          34.00
# mean                 11.21          20.47                          42.47
# std                   2.72          10.02                          11.71
# min                   5.94           7.84                          18.97
# 25%                   9.10          12.26                          33.25
# 50%                  10.79          21.68                          43.30
# 75%                  13.28          23.81                          52.08
# max                  16.84          50.02                          66.45

# %%
# group by Borough and drop unnecessary columns, then sort by density so that the barchart can be ordered
df_sorted = df_merged.sort_values("Women with tertiary educ perc", ascending=False)
df_sorted.head(3)
# Out:
#          Poverty rate  Contraception  Gender wage gap  Unemployment  \
# Country
# Canada          11.80          90.90            17.60          9.48
# Finland          6.50          90.40            18.90          7.83
# Israel          16.90          68.30            22.70          4.61
#
#          Education spendings  Press Freedom  Women with tertiary educ perc
# Country
# Canada                 13.21          15.29                          66.45
# Finland                13.48           7.93                          56.02
# Israel                 10.96          30.84                          55.08

# %%
# create bar chart

sns.set(style="whitegrid")
#sns.set_theme(style='darkgrid')
plt.figure(figsize=(9, 14))

ax = sns.barplot( x="Women with tertiary educ perc",
                  y=df_sorted.index.values, 
                 #hue="room_type",
                  data=df_sorted,
                  order = df_sorted.index.values,
                  palette="crest_r")

#plt.xlabel("Airbnb Listings Density per Borough (1/ha)", size=14)
plt.xlabel(None)
plt.ylabel(None)

plt.savefig("Percentage of Women with Higher education.png", bbox_inches = 'tight')

# %%
# using a quick plot to visualise the distribution of the variables
sns.set(style="white")
sns.pairplot(data=df_merged, markers=".", diag_kind='kde', corner=True)

# %%
# code below from Philip Wilkinson : https://github.com/PhilipDW183/Convenience_store/blob/main/Convenience%20store%20exploration.ipynb

#set the columns we are interested in
columns = ['Poverty rate',
           'Contraception', 
           'Gender wage gap', 
           'Unemployment',
           'Education spendings', 
           'Press Freedom'
          ]

#set the histogram titles
hist_titles = ["Poverty rate distribution",
              "Contraception distribution",
              "Gender wage gap distribution",
              "Unemployment distribution",
              "Education spending distribution",
              "Press Freedom"]
#set the acis labels
axis_labels = ['Poverty rate',
           'Contraception', 
           'Gender wage gap', 
           'Unemployment',
           'Education spendings', 
           'Press Freedom'
          ]

#create a base axis for the plots
fig, ax = plt.subplots(3,2, figsize = (20,20))
#flatten the axis to make it easy to iteratre over
axis = ax.flatten()

#iterate over each columns using the labels information already set up
for i, col in enumerate(columns):
    
    #create the histogram using the column
    df_merged[col].hist(bins = 10, ax = axis[i],
                                       color = "blue",
                                       alpha = 0.7)
    #add label information
    axis[i].set_title(hist_titles[i], fontsize = 18, pad = 18)
    axis[i].set_ylabel("Frequency", fontsize  =12, labelpad = 12)
    axis[i].set_xlabel(f"{axis_labels[i]}", fontsize = 12, labelpad = 12)
    axis[i].tick_params(axis = "both", labelsize = 12)

#remove the unused axis
#axis[5].set_axis_off()
#keep the layout tight
plt.tight_layout()
#show the plot 
plt.show()

# %%
# plot histogram of the log transforme listings distribution 
df_merged['Women with tertiary educ perc'].plot.hist(bins=10)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# NOTE:
# most of the distributions are slightly skewed

# %%
#create a base axis for the plots
fig, ax = plt.subplots(2,3, figsize = (18,13))
#flatten the axis to make it easy to iteratre over
axis = ax.flatten()

#iterate over each columns using the labels information already set up
for i, col in enumerate(columns):
    
    #sns.scatterplot(data=df_merged, x=col, y="Women with tertiary educ perc")
    # plot 
    axis[i].scatter(df_merged[col], df_merged["Women with tertiary educ perc"]) 
  #  axis[i].set_title(hist_titles[i], fontsize = 18, pad = 18)
    axis[i].set_ylabel("Women with tertiary educ perc", fontsize  =12, labelpad = 12)
    axis[i].set_xlabel(f"{axis_labels[i]}", fontsize = 12, labelpad = 12)
    axis[i].tick_params(axis = "both", labelsize = 12)

# %% [markdown]
# there seems to be no aparent linear relationship between y and x.
# Gender wage gap, unemployment and press freedum seeem to have a curvilinear relationship

# %%
#df.price.plot.box() # boxplot
#create a base axis for the plots
fig, ax = plt.subplots(2,3, figsize = (20,13))
#flatten the axis to make it easy to iteratre over
axis = ax.flatten()

#iterate over each columns using the labels information already set up
for i, col in enumerate(columns):
    
    #sns.scatterplot(data=df_merged, x=col, y="Women with tertiary educ perc")
    # plot 
    axis[i].boxplot(df_merged[col], positions = [i])
   # axis[i].set_title(hist_titles[i], fontsize = 18, pad = 18)
   # axis[i].set_ylabel("Women with tertiary educ perc", fontsize  =12, labelpad = 12)
    axis[i].set_xlabel(f"{axis_labels[i]}", fontsize = 12, labelpad = 12)
    axis[i].tick_params(axis = "both", labelsize = 12)

# %%
df_merged.boxplot(column=columns,
            figsize=(14,10))
# Out:
# <AxesSubplot:>

# %% [markdown]
# Boxplot show the outlier in contracepiton, gender wage, unemployment and press freedom(press control)

# %% [markdown]
# ## MLR
# running the mlr despite the fact that the requirementsa are not fullfilled

# %%
plt.rcParams["axes.grid"] = False
f = plt.figure(figsize=(8, 5))
plt.matshow(df_merged.corr(), fignum=f.number, cmap='viridis')
plt.xticks(range(df_merged.shape[1]), df_merged.columns, fontsize=14, rotation=90)
plt.yticks(range(df_merged.shape[1]), df_merged.columns, fontsize=14)
cb = plt.colorbar()
cb.ax.tick_params(labelsize=14)
plt.title('Correlation Matrix', fontsize=16)
# Out:
# Text(0.5, 1.0, 'Correlation Matrix')

# %%
# calculating VIF
# This function is adjusted from: https://stackoverflow.com/a/51329496/4667568
from statsmodels.stats.outliers_influence import variance_inflation_factor 
from statsmodels.tools.tools import add_constant

def drop_column_using_vif_(df, thresh=5):
    '''
    Calculates VIF each feature in a pandas dataframe, and repeatedly drop the columns with the highest VIF
    A constant must be added to variance_inflation_factor or the results will be incorrect

    :param df: the pandas dataframe containing only the predictor features, not the response variable
    :param thresh: (default 5) the threshould VIF value. If the VIF of a variable is greater than thresh, it should be removed from the dataframe
    :return: dataframe with multicollinear features removed
    '''
    while True:
        # adding a constatnt item to the data
        df_with_const = add_constant(df)

        vif_df = pd.Series([variance_inflation_factor(df_with_const.values, i) 
               for i in range(df_with_const.shape[1])], name= "VIF",
              index=df_with_const.columns).to_frame()

        # drop the const
        vif_df = vif_df.drop('const')
        
        # if the largest VIF is above the thresh, remove a variable with the largest VIF
        # If there are multiple variabels with VIF>thresh, only one of them is removed. This is because we want to keep as many variables as possible
        if vif_df.VIF.max() > thresh:
            # If there are multiple variables with the maximum VIF, choose the first one
            index_to_drop = vif_df.index[vif_df.VIF == vif_df.VIF.max()].tolist()[0]
            print('Dropping: {}'.format(index_to_drop))
            df = df.drop(columns = index_to_drop)
        else:
            # No VIF is above threshold. Exit the loop
            break

    return df

# %%
# using VIF to drop highly correlated variables

df_predictors_selected_VIF = drop_column_using_vif_(df_merged.drop('Women with tertiary educ perc', axis=1), thresh=5)
# Note that there is a 'while' loop in the drop_column_using_vif_. In each iteration, one variable is dropped.
print("The columns remaining after VIF selection are:")
print(df_predictors_selected_VIF.columns)
# Out:
# The columns remaining after VIF selection are:
# Index(['Poverty rate', 'Contraception', 'Gender wage gap', 'Unemployment',
#        'Education spendings', 'Press Freedom'],
#       dtype='object')
# /opt/conda/envs/sds2021/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)

# %%
from sklearn.linear_model import LinearRegression
import statsmodels.api as sm
model_MLR = sm.OLS(endog=df_merged[['Women with tertiary educ perc']], exog=sm.add_constant(df_predictors_selected_VIF)).fit()
model_MLR.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                   OLS Regression Results
# =========================================================================================
# Dep. Variable:     Women with tertiary educ perc   R-squared:                       0.485
# Model:                                       OLS   Adj. R-squared:                  0.370
# Method:                            Least Squares   F-statistic:                     4.230
# Date:                           Sat, 08 Jan 2022   Prob (F-statistic):            0.00397
# Time:                                   17:19:46   Log-Likelihood:                -120.12
# No. Observations:                             34   AIC:                             254.2
# Df Residuals:                                 27   BIC:                             264.9
# Df Model:                                      6
# Covariance Type:                       nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                  49.4529     26.923      1.837      0.077      -5.789     104.695
# Poverty rate            0.3594      0.627      0.573      0.571      -0.928       1.646
# Contraception          -0.3563      0.275     -1.297      0.205      -0.920       0.207
# Gender wage gap         0.6774      0.293      2.315      0.028       0.077       1.278
# Unemployment            0.2478      0.545      0.455      0.653      -0.871       1.367
# Education spendings     1.7653      0.826      2.138      0.042       0.071       3.459
# Press Freedom          -0.6252      0.253     -2.467      0.020      -1.145      -0.105
# ==============================================================================
# Omnibus:                        0.618   Durbin-Watson:                   2.189
# Prob(Omnibus):                  0.734   Jarque-Bera (JB):                0.208
# Skew:                          -0.188   Prob(JB):                        0.901
# Kurtosis:                       3.076   Cond. No.                     1.47e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.47e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
sns.set_theme( style='darkgrid', palette='deep', font_scale=1, color_codes=True, rc=None)
# plot 

f = plt.figure(figsize=(8, 5))
plt.scatter(model_MLR.fittedvalues, model_MLR.resid)
# adding title and labels
plt.xlabel('Fitted unemployment rate')
plt.ylabel('Residual')
plt.title('Residual vs. Fitted Plot of unemployment rate')
plt.axhline(y = 0, color = "black", linestyle = "-")
plt.show()

#plt.savefig("residuals.png")

# %% [markdown]
# ## normalise

# %%
to_ln = ['Poverty rate',
           'Contraception', 
          'Gender wage gap', 
           'Unemployment',
          # 'Education spendings', 
           'Press Freedom',
           'Women with tertiary educ perc'
           ]

# %%
# add a column taking the log 
for col in to_ln:
    df_merged["ln_"+ col] = np.log(df_merged[col])
    
#joined_wards["ln_listings_density"]= np.log(joined_wards["listings_density"])

# %%
#df_merged["Gender gap2"] = df_merged['Gender wage gap']**2

# %%
df_merged
# Out:
#                  Poverty rate  Contraception  Gender wage gap  Unemployment  \
# Country
# Australia               12.40          85.60            11.70          6.61
# Austria                  9.40          88.00            14.90          5.77
# Belgium                  8.20          90.10             4.20          6.01
# Canada                  11.80          90.90            17.60          9.48
# Chile                   16.50          84.80            12.50         11.51
# Czech Republic           6.10          85.70            14.70          2.94
# Denmark                  6.10          87.70             4.90          5.66
# Estonia                 16.30          80.30            28.30          6.46
# Finland                  6.50          90.40            18.90          7.83
# France                   8.50          95.50            13.70          8.62
# Germany                 10.40          91.00            15.30          4.31
# Greece                  12.10          63.50             4.50         16.85
# Hungary                 17.90          80.20             5.10          4.35
# Ireland                  9.00          87.70            10.60          5.92
# Israel                  16.90          68.30            22.70          4.61
# Italy                   13.90          72.00             5.60          9.31
# Japan                   15.70          67.30            23.50          2.97
# Korea, Rep.             16.70          81.80            32.50          4.07
# Latvia                  17.50          80.50            21.10          8.19
# Lithuania               15.50          69.70            12.50          8.43
# Mexico                  16.60          79.80            18.80          4.71
# Netherlands              8.30          88.60            14.10          4.09
# New Zealand             10.90          85.60             6.50          4.55
# Norway                   8.40          88.60             5.00          4.62
# Poland                   9.80          71.80            11.50          3.55
# Portugal                10.40          77.60             9.60          7.20
# Slovak Republic          7.70          79.20            13.90          6.79
# Slovenia                 7.50          75.80             5.00          5.17
# Spain                   14.20          83.50            11.50         15.67
# Sweden                   8.90          86.70             7.60          8.45
# Switzerland              9.20          88.90            15.10          4.94
# Turkey                  17.20          60.10             6.90         13.92
# United Kingdom          11.70          86.50            16.00          4.34
# United States           17.80          78.40            18.50          8.31
#
#                  Education spendings  Press Freedom  \
# Country
# Australia                      11.54          20.21
# Austria                        12.91          15.78
# Belgium                        14.23          12.57
# Canada                         13.21          15.29
# Chile                          10.07          27.31
# Czech Republic                 10.18          23.57
# Denmark                        16.26           8.13
# Estonia                         9.89          12.61
# Finland                        13.48           7.93
# France                         13.71          22.92
# Germany                        13.78          12.16
# Greece                          7.97          28.80
# Hungary                         9.30          30.84
# Ireland                         8.63          12.60
# Israel                         10.96          30.84
# Italy                          10.45          23.69
# Japan                          12.39          28.86
# Korea, Rep.                     8.75          23.70
# Latvia                          8.09          18.56
# Lithuania                       8.14          21.19
# Mexico                          7.21          45.45
# Netherlands                    11.65           9.96
# New Zealand                    13.18          10.69
# Norway                         16.49           7.84
# Poland                          9.06          28.65
# Portugal                       10.80          11.83
# Slovak Republic                 9.24          22.67
# Slovenia                       10.79          22.64
# Spain                          10.53          22.16
# Sweden                         16.84           9.25
# Switzerland                     8.84          10.62
# Turkey                          5.94          50.02
# United Kingdom                 13.30          22.93
# United States                  13.47          23.85
#
#                  Women with tertiary educ perc  ln_Poverty rate  \
# Country
# Australia                                54.41             2.52
# Austria                                  34.01             2.24
# Belgium                                  46.96             2.10
# Canada                                   66.45             2.47
# Chile                                    25.63             2.80
# Czech Republic                           27.33             1.81
# Denmark                                  45.87             1.81
# Estonia                                  52.44             2.79
# Finland                                  56.02             1.87
# France                                   42.54             2.14
# Germany                                  28.97             2.34
# Greece                                   34.51             2.49
# Hungary                                  31.33             2.88
# Ireland                                  53.42             2.20
# Israel                                   55.08             2.83
# Italy                                    23.01             2.63
# Japan                                    53.90             2.75
# Korea, Rep.                              48.52             2.82
# Latvia                                   46.25             2.86
# Lithuania                                51.10             2.74
# Mexico                                   18.97             2.81
# Netherlands                              43.32             2.12
# New Zealand                              43.27             2.39
# Norway                                   51.23             2.13
# Poland                                   38.84             2.28
# Portugal                                 33.00             2.34
# Slovak Republic                          31.60             2.04
# Slovenia                                 43.02             2.01
# Spain                                    42.66             2.65
# Sweden                                   52.18             2.19
# Switzerland                              42.17             2.22
# Turkey                                   20.75             2.84
# United Kingdom                           51.79             2.46
# United States                            53.42             2.88
#
#                  ln_Contraception  ln_Gender wage gap  ln_Unemployment  \
# Country
# Australia                    4.45                2.46             1.89
# Austria                      4.48                2.70             1.75
# Belgium                      4.50                1.44             1.79
# Canada                       4.51                2.87             2.25
# Chile                        4.44                2.53             2.44
# Czech Republic               4.45                2.69             1.08
# Denmark                      4.47                1.59             1.73
# Estonia                      4.39                3.34             1.87
# Finland                      4.50                2.94             2.06
# France                       4.56                2.62             2.15
# Germany                      4.51                2.73             1.46
# Greece                       4.15                1.50             2.82
# Hungary                      4.38                1.63             1.47
# Ireland                      4.47                2.36             1.78
# Israel                       4.22                3.12             1.53
# Italy                        4.28                1.72             2.23
# Japan                        4.21                3.16             1.09
# Korea, Rep.                  4.40                3.48             1.40
# Latvia                       4.39                3.05             2.10
# Lithuania                    4.24                2.53             2.13
# Mexico                       4.38                2.93             1.55
# Netherlands                  4.48                2.65             1.41
# New Zealand                  4.45                1.87             1.52
# Norway                       4.48                1.61             1.53
# Poland                       4.27                2.44             1.27
# Portugal                     4.35                2.26             1.97
# Slovak Republic              4.37                2.63             1.92
# Slovenia                     4.33                1.61             1.64
# Spain                        4.42                2.44             2.75
# Sweden                       4.46                2.03             2.13
# Switzerland                  4.49                2.71             1.60
# Turkey                       4.10                1.93             2.63
# United Kingdom               4.46                2.77             1.47
# United States                4.36                2.92             2.12
#
#                  ln_Press Freedom  ln_Women with tertiary educ perc
# Country
# Australia                    3.01                              4.00
# Austria                      2.76                              3.53
# Belgium                      2.53                              3.85
# Canada                       2.73                              4.20
# Chile                        3.31                              3.24
# Czech Republic               3.16                              3.31
# Denmark                      2.10                              3.83
# Estonia                      2.53                              3.96
# Finland                      2.07                              4.03
# France                       3.13                              3.75
# Germany                      2.50                              3.37
# Greece                       3.36                              3.54
# Hungary                      3.43                              3.44
# Ireland                      2.53                              3.98
# Israel                       3.43                              4.01
# Italy                        3.17                              3.14
# Japan                        3.36                              3.99
# Korea, Rep.                  3.17                              3.88
# Latvia                       2.92                              3.83
# Lithuania                    3.05                              3.93
# Mexico                       3.82                              2.94
# Netherlands                  2.30                              3.77
# New Zealand                  2.37                              3.77
# Norway                       2.06                              3.94
# Poland                       3.36                              3.66
# Portugal                     2.47                              3.50
# Slovak Republic              3.12                              3.45
# Slovenia                     3.12                              3.76
# Spain                        3.10                              3.75
# Sweden                       2.22                              3.95
# Switzerland                  2.36                              3.74
# Turkey                       3.91                              3.03
# United Kingdom               3.13                              3.95
# United States                3.17                              3.98

# %%
to_ln = ['Poverty rate',
           'Contraception', 
          'Gender wage gap', 
           'Unemployment',
          # 'Education spendings', 
           'Press Freedom',
           'Women with tertiary educ perc'
           ]

# %%
df_norm = df_merged.drop(['Poverty rate',
           'Contraception', 
          'Gender wage gap', 
           'Unemployment', 
           'Press Freedom',
           'Women with tertiary educ perc'], axis=1)

# %%
# using a quick plot to visualise the distribution of the variables
sns.set(style="white")
sns.pairplot(data=df_norm , markers=".", diag_kind='kde', corner=False)

# %%
#from sklearn.linear_model import LinearRegression
#import statsmodels.api as sm
model_2 = sm.OLS(endog=df_norm[['ln_Women with tertiary educ perc']], exog=sm.add_constant(df_norm.drop("ln_Women with tertiary educ perc",axis=1))).fit()
model_2.summary()
# Out:
# /opt/conda/envs/sds2021/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                    OLS Regression Results
# ============================================================================================
# Dep. Variable:     ln_Women with tertiary educ perc   R-squared:                       0.431
# Model:                                          OLS   Adj. R-squared:                  0.305
# Method:                               Least Squares   F-statistic:                     3.411
# Date:                              Sat, 08 Jan 2022   Prob (F-statistic):             0.0123
# Time:                                      17:28:34   Log-Likelihood:                 1.4154
# No. Observations:                                34   AIC:                             11.17
# Df Residuals:                                    27   BIC:                             21.85
# Df Model:                                         6
# Covariance Type:                          nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                   6.4112      2.818      2.275      0.031       0.630      12.192
# Education spendings     0.0476      0.023      2.036      0.052      -0.000       0.096
# ln_Poverty rate         0.1216      0.191      0.635      0.530      -0.271       0.514
# ln_Contraception       -0.7092      0.600     -1.183      0.247      -1.940       0.521
# ln_Gender wage gap      0.2024      0.097      2.093      0.046       0.004       0.401
# ln_Unemployment         0.0165      0.114      0.145      0.886      -0.217       0.250
# ln_Press Freedom       -0.3248      0.144     -2.251      0.033      -0.621      -0.029
# ==============================================================================
# Omnibus:                        1.931   Durbin-Watson:                   2.274
# Prob(Omnibus):                  0.381   Jarque-Bera (JB):                1.775
# Skew:                          -0.515   Prob(JB):                        0.412
# Kurtosis:                       2.562   Cond. No.                         852.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
sns.set_theme( style='darkgrid', palette='deep', font_scale=1, color_codes=True, rc=None)
# plot 

f = plt.figure(figsize=(8, 5))
plt.scatter(model_2.fittedvalues, model_2.resid)
# adding title and labels
plt.xlabel('Fitted unemployment rate')
plt.ylabel('Residual')
plt.title('Residual vs. Fitted Plot of unemployment rate')
plt.axhline(y = 0, color = "black", linestyle = "-")
plt.show()

plt.savefig("residuals.png")

# %%
df_norm.head(2)
# Out:
#            Education spendings  ln_Poverty rate  ln_Contraception  \
# Country
# Australia                11.54             2.52              4.45
# Austria                  12.91             2.24              4.48
#
#            ln_Gender wage gap  ln_Unemployment  ln_Press Freedom  \
# Country
# Australia                2.46             1.89              3.01
# Austria                  2.70             1.75              2.76
#
#            ln_Women with tertiary educ perc
# Country
# Australia                              4.00
# Austria                                3.53

# %%
# drop variables

# %%
df_drop= df_norm.drop(['ln_Contraception','ln_Poverty rate',"ln_Unemployment"], axis=1)

# %%
model_3 = sm.OLS(endog=df_drop[['ln_Women with tertiary educ perc']], exog=sm.add_constant(df_drop.drop("ln_Women with tertiary educ perc", axis=1))).fit()
model_3.summary()
# Out:
# /opt/conda/envs/sds2021/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                    OLS Regression Results
# ============================================================================================
# Dep. Variable:     ln_Women with tertiary educ perc   R-squared:                       0.378
# Model:                                          OLS   Adj. R-squared:                  0.315
# Method:                               Least Squares   F-statistic:                     6.065
# Date:                              Sat, 08 Jan 2022   Prob (F-statistic):            0.00236
# Time:                                      17:38:21   Log-Likelihood:               -0.11632
# No. Observations:                                34   AIC:                             8.233
# Df Residuals:                                    30   BIC:                             14.34
# Df Model:                                         3
# Covariance Type:                          nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                   3.4380      0.583      5.893      0.000       2.246       4.629
# Education spendings     0.0365      0.022      1.668      0.106      -0.008       0.081
# ln_Gender wage gap      0.1845      0.081      2.283      0.030       0.019       0.350
# ln_Press Freedom       -0.2043      0.119     -1.710      0.098      -0.448       0.040
# ==============================================================================
# Omnibus:                        2.713   Durbin-Watson:                   2.194
# Prob(Omnibus):                  0.258   Jarque-Bera (JB):                2.471
# Skew:                          -0.619   Prob(JB):                        0.291
# Kurtosis:                       2.543   Cond. No.                         162.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
sns.set_theme( style='darkgrid', palette='deep', font_scale=1, color_codes=True, rc=None)
# plot 

f = plt.figure(figsize=(8, 5))
plt.scatter(model_3.fittedvalues, model_3.resid)
plt.axhline(y = 0, color = "black", linestyle = "-")
# adding title and labels
plt.xlabel('Fitted unemployment rate')
plt.ylabel('Residual')
plt.title('Residual vs. Fitted Plot of unemployment rate')
plt.show()

plt.savefig("residuals.png")

# %% [markdown]
# ## standardise

# %%
#df_stand = df_norm.set_index('Country')

# %%
df_norm.columns
# Out:
# Index(['Education spendings', 'ln_Poverty rate', 'ln_Contraception',
#        'ln_Gender wage gap', 'ln_Unemployment', 'ln_Press Freedom',
#        'ln_Women with tertiary educ perc'],
#       dtype='object')

# %%
columns=['Education spendings', 'ln_Poverty rate', 'ln_Contraception',
       'ln_Gender wage gap', 'ln_Unemployment', 'ln_Press Freedom',
       'ln_Women with tertiary educ perc']

# %%
from scipy.stats import zscore
df_stand= df_norm.apply(zscore)

# %%
df_stand.head()
# Out:
#            Education spendings  ln_Poverty rate  ln_Contraception  \
# Country
# Australia                 0.12             0.28              0.49
# Austria                   0.63            -0.55              0.75
# Belgium                   1.13            -0.96              0.96
# Canada                    0.74             0.13              1.04
# Chile                    -0.43             1.13              0.41
#
#            ln_Gender wage gap  ln_Unemployment  ln_Press Freedom  \
# Country
# Australia                0.02             0.11              0.21
# Austria                  0.45            -0.20             -0.30
# Belgium                 -1.81            -0.11             -0.77
# Canada                   0.75             0.95             -0.37
# Chile                    0.14             1.39              0.83
#
#            ln_Women with tertiary educ perc
# Country
# Australia                              0.95
# Austria                               -0.58
# Belgium                                0.47
# Canada                                 1.60
# Chile                                 -1.50

# %%
# quick plot to visualise the results
sns.set(style="white")
sns.pairplot(df_stand, markers=".", height=3, diag_kind='kde');

# %%
clustA = df_stand

# %%
#import the necessary libraries
from sklearn import metrics
from sklearn.cluster import KMeans

#create an empty list
list_SSE = []
#set the range of clusters to evaluate
min_k = 1
max_k = 11
range_k = range(min_k, max_k)

# %%
#iterate over the range
for i in range_k:
    #perform the clustering algorithm
    km = KMeans(n_clusters = i,
               init = "random",
               n_init = 10,
               max_iter = 300,
               tol = 1e-04, 
               random_state = 22)
    #fit this to the data
    km.fit(clustA[columns])
    #add the SEE score
    list_SSE.append(km.inertia_)

# %%
#create the base plots
fig, ax = plt.subplots(1,1, figsize = (10,10))

#add the data to the axis
ax.plot(range_k, list_SSE, marker = "o")

#add the necessary labels
ax.set_xlabel("Number of Clusters", fontsize = 20, labelpad = 20)
ax.set_ylabel("SSE", fontsize =20, labelpad = 20)
ax.set_title("Kmeans Elbow plot", fontsize = 25, pad = 20)

plt.show()

# %%
#for the silhouette score
import random

#create an empty list
silhouette = []

#iteratre over the number of clusters to evaluate
for i in range(2,10):
    
    #create an empty list to hold the averages
    average = []
    #perform the clustering algorithm several times for each number of clusters
    for x in range(1,10):
        #set the number of clusters
        k_cluster = i
        #generate a arandom seed number
        random_seed = random.randint(1,101)
        #apply the KMeans clustering algorithm
        kmeans_method = KMeans(n_clusters = k_cluster,
                              random_state = random_seed)
        kmeans_method.fit(clustA[columns])
        #extract the labels
        labels = kmeans_method.labels_
        #extract the silhouette score
        a = metrics.silhouette_score(clustA[columns], labels)
        #append the result
        average.append(a)
    #clauclate the average silhouette score for each number of clusters 
    silhouette.append(sum(average)/len(average))

# %%
#create a base axis
fig, ax = plt.subplots(1,1, figsize = (10,10))

#plot the results
ax.plot(range(2,10), silhouette, marker = "o")

#add the lbels
ax.set_xlabel("Number of Clusters", fontsize = 20, labelpad = 20)
ax.set_ylabel("Silhoute score", fontsize =20, labelpad = 20)
ax.set_title("Kmeans silhouette plot", fontsize = 25, pad = 20)

plt.show()

# %%
#combine both plots
fig, ax = plt.subplots(1,2, figsize = (15,8))

ax[0].plot(range(2,10), silhouette, marker = "o")
ax[0].set_xlabel("Number of Clusters", fontsize = 20, labelpad = 20)
ax[0].set_ylabel("Silhoute score", fontsize =20, labelpad = 20)
ax[0].set_title("Kmeans silhouette plot", fontsize = 25, pad = 20)

ax[1].plot(range_k, list_SSE, marker = "o")
ax[1].set_xlabel("Number of Clusters", fontsize = 20, labelpad = 20)
ax[1].set_ylabel("SSE", fontsize =20, labelpad = 20)
ax[1].set_title("Kmeans Elbow plot", fontsize = 25, pad = 20)
# Out:
# Text(0.5, 1.0, 'Kmeans Elbow plot')

# %%
#perform the clustering with the chosen number of clusters
kmeans_method = KMeans(n_clusters = 5,
                        random_state = 42,
                      n_init = 10)
kmeans_method.fit(clustA[columns])


#creating plots for the results to understand the means

#set the titles
titles = [ "Education spendings",
              "ln_Poverty rate",
              "ln_Contraception",
              "ln_Gender wage gap",
              "ln_Unemployment",
              "ln_Press Freedom",
              "ln_Women with tertiary educ perc" ]
#set the labels
ylabels = ["Education spendings",
              "ln_Poverty rate",
              "ln_Contraception",
              "ln_Gender wage gap",
              "ln_Unemployment",
              "ln_Press Freedom",
              "ln_Women with tertiary educ perc"]
#extract the cluster labels and add these back to the data
labels = kmeans_method.labels_
df_merged["labels"] = labels
df_merged["labels"] = df_merged["labels"] + 1

#create a base plot
fig, ax = plt.subplots(4,2, figsize = (18,18))
#flatten the axis
axis = ax.flatten()

#iterate over each column to create plots for each 
for i, col in enumerate(columns):
    #create an empty dictionary
    col_dict = {}
     #iterate over each label
        
    for label in df_merged["labels"].unique().tolist():
        #crete a new dataframe for each label
        label_df = df_merged[df_merged["labels"] == label]
        #add the mean to the dataframe
        col_dict[label] = label_df[col].mean()
    #convert the dictionary to a dataframe
    column_df = pd.DataFrame.from_dict(col_dict, orient = "index")
    #reset the index
    column_df.reset_index(inplace=True)
    #sort the values by the index
    column_df.sort_values(by = "index", inplace=True)

        #plot the results
    axis[i].plot(column_df["index"], column_df[0],
                marker = "o")
    
    #set the plots up
    axis[i].set_title(titles[i], fontsize = 12, pad = 12)
    axis[i].set_xlabel("Cluster", fontsize = 12, labelpad = 12)
    axis[i].set_ylabel(ylabels[i], fontsize =12, labelpad = 12)
    axis[i].tick_params(axis = "both", labelsize = 12)


#set the layout to tight so no overalp
plt.tight_layout()

# %%
#extract the number of wards within each clusterc 
df_merged["labels"].value_counts()
# Out:
# 4    12
# 1     7
# 3     6
# 5     5
# 2     4
# Name: labels, dtype: int64

# %%
df_merged.head()
# Out:
#            Poverty rate  Contraception  Gender wage gap  Unemployment  \
# Country
# Australia          12.4           85.6             11.7          6.61
# Austria             9.4           88.0             14.9          5.77
# Belgium             8.2           90.1              4.2          6.01
# Canada             11.8           90.9             17.6          9.48
# Chile              16.5           84.8             12.5         11.51
#
#            Education spendings  Press Freedom  Women with tertiary educ perc  \
# Country
# Australia               11.537          20.21                      54.412212
# Austria                 12.905          15.78                      34.013531
# Belgium                 14.232          12.57                      46.957001
# Canada                  13.205          15.29                      66.451424
# Chile                   10.066          27.31                      25.628315
#
#            ln_Poverty rate  ln_Contraception  ln_Gender wage gap  \
# Country
# Australia         2.517696          4.449685            2.459589
# Austria           2.240710          4.477337            2.701361
# Belgium           2.104134          4.500920            1.435085
# Canada            2.468100          4.509760            2.867899
# Chile             2.803360          4.440296            2.525729
#
#            ln_Unemployment  ln_Press Freedom  \
# Country
# Australia         1.888584          3.006178
# Austria           1.752672          2.758743
# Belgium           1.793425          2.531313
# Canada            2.249184          2.727199
# Chile             2.443216          3.307253
#
#            ln_Women with tertiary educ perc  labels
# Country
# Australia                          3.996589       1
# Austria                            3.526758       4
# Belgium                            3.849232       5
# Canada                             4.196471       1
# Chile                              3.243698       3

# %%
clusters = df_merged.reset_index()
clusters.head(2)
# Out:
#      Country  Poverty rate  Contraception  Gender wage gap  Unemployment  \
# 0  Australia          12.4           85.6             11.7          6.61
# 1    Austria           9.4           88.0             14.9          5.77
#
#    Education spendings  Press Freedom  Women with tertiary educ perc  \
# 0               11.537          20.21                      54.412212
# 1               12.905          15.78                      34.013531
#
#    ln_Poverty rate  ln_Contraception  ln_Gender wage gap  ln_Unemployment  \
# 0         2.517696          4.449685            2.459589         1.888584
# 1         2.240710          4.477337            2.701361         1.752672
#
#    ln_Press Freedom  ln_Women with tertiary educ perc  labels
# 0          3.006178                          3.996589       1
# 1          2.758743                          3.526758       4

# %%
clusters.groupby('labels')['Country']

# %%
groups = clusters.groupby('labels')['Country'].agg(lambda
                             x: list(x))
  
print(groups)
# Out:
# labels
# 1    [Australia, Canada, Estonia, Latvia, Lithuania...
# 2                 [Israel, Japan, Korea, Rep., Poland]
# 3      [Chile, Greece, Hungary, Italy, Mexico, Turkey]
# 4    [Austria, Czech Republic, Finland, France, Ger...
# 5      [Belgium, Denmark, New Zealand, Norway, Sweden]
# Name: Country, dtype: object

# %%
print(type(groups))
# Out:
# <class 'pandas.core.series.Series'>

# %%
test_dict= groups.to_dict()
test_dict
# Out:
# {1: ['Australia',
#   'Canada',
#   'Estonia',
#   'Latvia',
#   'Lithuania',
#   'Spain',
#   'United States'],
#  2: ['Israel', 'Japan', 'Korea, Rep.', 'Poland'],
#  3: ['Chile', 'Greece', 'Hungary', 'Italy', 'Mexico', 'Turkey'],
#  4: ['Austria',
#   'Czech Republic',
#   'Finland',
#   'France',
#   'Germany',
#   'Ireland',
#   'Netherlands',
#   'Portugal',
#   'Slovak Republic',
#   'Slovenia',
#   'Switzerland',
#   'United Kingdom'],
#  5: ['Belgium', 'Denmark', 'New Zealand', 'Norway', 'Sweden']}

# %%
# clust_table = pd.DataFrame.from_dict(test_dict)

# %%
test = pd.DataFrame(groups)
test
# Out:
#                                                   Country
# labels
# 1       [Austria, Czech Republic, France, Germany, Ire...
# 2                  [Chile, Hungary, Italy, Mexico, Spain]
# 3       [Australia, Canada, Estonia, Israel, Japan, Ko...
# 4                                        [Greece, Turkey]
# 5       [Belgium, Denmark, Finland, New Zealand, Norwa...

# %%
#from sklearn.linear_model import LinearRegression
#import statsmodels.api as sm
model_4 = sm.OLS(endog=df_stand[['ln_Women with tertiary educ perc']], exog=sm.add_constant(df_stand.drop("ln_Women with tertiary educ perc",axis=1))).fit()
model_4.summary()
# Out:
# /opt/conda/envs/sds2021/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                    OLS Regression Results
# ============================================================================================
# Dep. Variable:     ln_Women with tertiary educ perc   R-squared:                       0.431
# Model:                                          OLS   Adj. R-squared:                  0.305
# Method:                               Least Squares   F-statistic:                     3.411
# Date:                              Sun, 09 Jan 2022   Prob (F-statistic):             0.0123
# Time:                                      15:28:55   Log-Likelihood:                -38.653
# No. Observations:                                34   AIC:                             91.31
# Df Residuals:                                    27   BIC:                             102.0
# Df Model:                                         6
# Covariance Type:                          nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                1.013e-15      0.145   6.98e-15      1.000      -0.298       0.298
# Education spendings     0.4140      0.203      2.036      0.052      -0.003       0.831
# ln_Poverty rate         0.1324      0.208      0.635      0.530      -0.295       0.560
# ln_Contraception       -0.2543      0.215     -1.183      0.247      -0.695       0.187
# ln_Gender wage gap      0.3676      0.176      2.093      0.046       0.007       0.728
# ln_Unemployment         0.0233      0.160      0.145      0.886      -0.305       0.352
# ln_Press Freedom       -0.5124      0.228     -2.251      0.033      -0.979      -0.045
# ==============================================================================
# Omnibus:                        1.931   Durbin-Watson:                   2.274
# Prob(Omnibus):                  0.381   Jarque-Bera (JB):                1.775
# Skew:                          -0.515   Prob(JB):                        0.412
# Kurtosis:                       2.562   Cond. No.                         3.24
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
df_drop2= df_norm.drop(['ln_Contraception','ln_Poverty rate',"ln_Unemployment"], axis=1)

# %%
model_5 = sm.OLS(endog=df_drop2[['ln_Women with tertiary educ perc']], exog=sm.add_constant(df_drop2.drop("ln_Women with tertiary educ perc", axis=1))).fit()
model_5.summary()
# Out:
# /opt/conda/envs/sds2021/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                    OLS Regression Results
# ============================================================================================
# Dep. Variable:     ln_Women with tertiary educ perc   R-squared:                       0.378
# Model:                                          OLS   Adj. R-squared:                  0.315
# Method:                               Least Squares   F-statistic:                     6.065
# Date:                              Sun, 09 Jan 2022   Prob (F-statistic):            0.00236
# Time:                                      15:30:19   Log-Likelihood:               -0.11632
# No. Observations:                                34   AIC:                             8.233
# Df Residuals:                                    30   BIC:                             14.34
# Df Model:                                         3
# Covariance Type:                          nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                   3.4380      0.583      5.893      0.000       2.246       4.629
# Education spendings     0.0365      0.022      1.668      0.106      -0.008       0.081
# ln_Gender wage gap      0.1845      0.081      2.283      0.030       0.019       0.350
# ln_Press Freedom       -0.2043      0.119     -1.710      0.098      -0.448       0.040
# ==============================================================================
# Omnibus:                        2.713   Durbin-Watson:                   2.194
# Prob(Omnibus):                  0.258   Jarque-Bera (JB):                2.471
# Skew:                          -0.619   Prob(JB):                        0.291
# Kurtosis:                       2.543   Cond. No.                         162.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
#rename column names
df_merged.rename(columns = {'Subjective well-being (average ladder score, worst 0-10 best)':'Well being', 
                            'Demand for family planning satisfied by modern methods (% of females aged 15 to ':'Contraception',
                            'Gender wage gap (% of male median wage)':"Gender wage gap",
                            'CO₂ emissions from fuel combustion for electricity and heating per total electri': 'CO₂ emissions',
                            'Unemployment rate (% of total labor force)': 'Unemployment',
                            'Gini coefficient adjusted for top income': 'Gini',
                            'Poverty rate after taxes and transfers (%)':'Poverty rate'
                            'Government spending on health and education (% of GDP)':'Education spendings'
                    }, inplace = True)
